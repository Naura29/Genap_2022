# %% [markdown]
# <a href="https://colab.research.google.com/github/Naura29/Genap_2022/blob/main/Week1Naura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
from google.colab import files
spotify = files.upload()
# Out:
#      <input type="file" id="files-f20a6213-778e-45b4-958a-2bdc49ed9b88" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f20a6213-778e-45b4-958a-2bdc49ed9b88">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving spotify.csv to spotify.csv

# %%
spotify
# Out:
# {'spotify.csv': b'Date,Shape of You,Despacito,Something Just Like This,HUMBLE.,Unforgettable\n2017-01-06,12287078,,,,\n2017-01-07,13190270,,,,\n2017-01-08,13099919,,,,\n2017-01-09,14506351,,,,\n2017-01-10,14275628,,,,\n2017-01-11,14372699,,,,\n2017-01-12,14148108,,,,\n2017-01-13,14536236,275178.0,,,\n2017-01-14,14173311,1144886.0,,,\n2017-01-15,12889849,1288198.0,,,\n2017-01-16,14128468,1827581.0,,,\n2017-01-17,14158281,2177449.0,,,\n2017-01-18,14293365,2528408.0,,,\n2017-01-19,14252159,2893300.0,,,\n2017-01-20,14583344,3260014.0,,,\n2017-01-21,14100340,3853781.0,,,\n2017-01-22,12834029,3590914.0,,,\n2017-01-23,14102623,4217226.0,,,\n2017-01-24,14322902,4690718.0,,,\n2017-01-25,14505619,4975605.0,,,\n2017-01-26,14780816,5284138.0,,,\n2017-01-27,15514586,5787911.0,,,\n2017-01-28,14832215,6111181.0,,,\n2017-01-29,13064919,5292500.0,,,\n2017-01-30,14231127,5865825.0,,,\n2017-01-31,14822928,6415754.0,,,\n2017-02-01,15082574,6909578.0,,,\n2017-02-02,15188841,7154707.0,,,\n2017-02-03,15746
# ...

# %%
import io 
dp = pd.read_csv(io.StringIO(spotify['spotify.csv'].decode('utf-8')))
print(dp)
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# ...

# %%
dp.head()
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
# 2  2017-01-08      13099919        NaN                       NaN      NaN
# 3  2017-01-09      14506351        NaN                       NaN      NaN
# 4  2017-01-10      14275628        NaN                       NaN      NaN
#
#    Unforgettable
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,6))
# Line chart showing how spotify rankings evolved over time 
sns.lineplot(data=dp)

# %%
# Print the last five rows of the data
dp.tail()
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# 361      2869783.0
# 362      2743748.0
# 363      2441045.0
# 364      2622693.0
# 365      2627334.0

# %%
sns.lineplot(data=dp)

# %%
list(dp.columns)
# Out:
# ['Date',
#  'Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
sns.lineplot(data=dp['Shape of You'], label="Shape of You")
